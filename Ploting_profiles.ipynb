# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
expression_data = pd.read_csv('data/RNAseq_z_score_adjustedCombat_just_age_symbols.csv')

# %%
from ploting_profiles import *

# %%
gene_profile(expression_data, 'TNMD')

# %%
gene_profile(expression_data, 'HCFC1R1')

# %%
gene_profile(expression_data, 'FEZ2')

# %%
gene_profile(expression_data, 'CA3')

# %%
gene_profile(expression_data, 'PKIA')

# %%
gene_profile(expression_data, 'NT5C2')

# %%
gene_profile(expression_data, 'STUM')

# %%
gene_profile(expression_data, 'PPP6C')

# %%
gene_profile(expression_data, 'PSTPIP2')

# %%
gene_profile(expression_data, 'MTCO2P22')

# %%
gene_profile(expression_data, 'NPY6R')

# %%
gene_profile(expression_data, 'MTRNR2L10')
