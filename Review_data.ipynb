# %% [markdown]
# # Data reviewing
# This jupiter notebook is to see the data that we are going to work with in this part of the poject.

# %%
import pandas as pd

# %%
expression_data = pd.read_csv('data/RNAseq_z_score_adjustedCombat.csv')

# %%
expression_data.head()
# Out:
#         Sample  ENSG00000000003.14  ENSG00000000005.5  ENSG00000000419.12  \
# 0  SRR13388732           -0.024640          -0.027469           -0.007903
# 1  SRR13388733           -0.025765          -0.032593           -0.006575
# 2  SRR13388734           -0.030008          -0.036930           -0.005061
# 3  SRR13388735           -0.021340          -0.023615           -0.006280
# 4  SRR13388736           -0.019630          -0.034585           -0.005184
#
#    ENSG00000000457.13  ENSG00000000460.16  ENSG00000000938.12  \
# 0           -0.026124           -0.026015           -0.026864
# 1           -0.027678           -0.031369           -0.031862
# 2           -0.034131           -0.029369           -0.037718
# 3           -0.022375           -0.023463           -0.023325
# 4           -0.031186           -0.026442           -0.034297
#
#    ENSG00000000971.15  ENSG00000001036.13  ENSG00000001084.11  ...  \
# 0           -0.021406           -0.022678           -0.022670  ...
# ...

# %%
ensembl_to_symbol = pd.read_csv('data/ensmbl_list.csv', index_col = 0)
ensembl_to_symbol.head()
# Out:
#                 geneSymbol
# ensembl
# ENSG00000000003     TSPAN6
# ENSG00000000005       TNMD
# ENSG00000000419       DPM1
# ENSG00000000457      SCYL3
# ENSG00000000460   C1orf112

# %%
ensembl_to_symbol_dic = ensembl_to_symbol.to_dict('index')

# %%
ensembl_to_symbol_dic

# %%
ensembl_genes = expression_data.columns[1:-2]

# %%
ensembl_genes= [gene.split('.')[0] for gene in ensembl_genes ]

# %%
ensembl_genes[-10:]
# Out:
# Index(['ENSG00000285471.1', 'ENSG00000285472.1', 'ENSG00000285476.1',
#        'ENSG00000285480.1', 'ENSG00000285491.1', 'ENSG00000285505.1',
#        'ENSG00000285508.1', 'ENSG00000285509.1', 'Age', 'Experiment'],
#       dtype='object')

# %%
column_symbols = [ensembl_to_symbol_dic[ensemble]['geneSymbol'] for ensemble in ensembl_genes]
column_symbols[:10]
# Out:
# ['TSPAN6',
#  'TNMD',
#  'DPM1',
#  'SCYL3',
#  'C1orf112',
#  'FGR',
#  'CFH',
#  'FUCA2',
#  'GCLC',
#  'NFYA']

# %%
column_symbols_ = ['Sample']
column_symbols_.extend(column_symbols)

column_symbols_.extend(["Age", "Experiment"])

# %%
len(column_symbols_)
# Out:
# 34508

# %%
expression_data.columns = column_symbols_
expression_data.head()
# Out:
#         Sample    TSPAN6      TNMD      DPM1     SCYL3  C1orf112       FGR  \
# 0  SRR13388732 -0.024640 -0.027469 -0.007903 -0.026124 -0.026015 -0.026864
# 1  SRR13388733 -0.025765 -0.032593 -0.006575 -0.027678 -0.031369 -0.031862
# 2  SRR13388734 -0.030008 -0.036930 -0.005061 -0.034131 -0.029369 -0.037718
# 3  SRR13388735 -0.021340 -0.023615 -0.006280 -0.022375 -0.023463 -0.023325
# 4  SRR13388736 -0.019630 -0.034585 -0.005184 -0.031186 -0.026442 -0.034297
#
#         CFH     FUCA2      GCLC  ...  AC007846.2  AC134980.5  AC139491.7  \
# 0 -0.021406 -0.022678 -0.022670  ...   -0.027402   -0.027306   -0.027267
# 1 -0.016857 -0.026578 -0.023808  ...   -0.032615   -0.032575   -0.032619
# 2 -0.015247 -0.030479 -0.027006  ...   -0.037149   -0.038608   -0.038491
# 3 -0.020330 -0.021371 -0.022376  ...   -0.023713   -0.023718   -0.023678
# 4 -0.022105 -0.015811 -0.017068  ...   -0.034271   -0.033711   -0.034180
#
#    AC021097.2  AC135068.11  AC010616.2  AL034430.1  AP000646.1   Age  \
# ...

# %%
expression_data.to_csv('data/RNAseq_z_score_adjustedCombat_symbols.csv')
